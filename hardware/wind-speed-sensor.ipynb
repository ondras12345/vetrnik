# %% [markdown]
# # Wind speed sensor
# Requirements:
# - at least 2 readings / second
# - optical isolation
#   - this leaves pulse output & RS485 modbus
#
# Thoughts:
# - RS485 needs 3 pins (Rx, Tx, RE)
#
# Can we sample pulses fast enough?

# %%
# wind turbine can only handle 16 m/s
max_wind_speed = 20  # m/s
pulses_per_m = 20 / 1.75  # some random webpage says 20 pulses / s ==> 1.75 m/s
max_pulse_frequency = max_wind_speed * pulses_per_m
max_pulse_frequency
# Out:
# 228.57142857142858

# %%
# we need to sample at least 10x faster
10*max_pulse_frequency
# Out:
# 2285.714285714286

# %%
# that sounds reasonable
